# %% [markdown]
# # Hotel Booking Analysis

# %% [markdown]
# ## 1. Project Overview
# ## 2. Dataset Source
# ## 3. Load Dataset
# ## 4. Quick Inspection
# ## 5. Column Descriptions
# ## 6. Initial Data Quality Checks

# %%
import pandas as pd

df = pd.read_csv("../data/excel_cleaned/hotel_bookings_cleaned.csv")
df.shape
# Out:
# C:\Users\allur\AppData\Local\Temp\ipykernel_11996\3407306778.py:3: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/excel_cleaned/hotel_bookings_cleaned.csv")
# (119390, 33)
