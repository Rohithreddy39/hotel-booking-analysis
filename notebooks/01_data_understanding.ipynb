# %% [markdown]
# # Hotel Booking Analysis

# %% [markdown]
# ## 1. Project Overview
# ## 2. Dataset Source
# ## 3. Load Dataset
# ## 4. Quick Inspection
# ## 5. Column Descriptions
# ## 6. Initial Data Quality Checks
